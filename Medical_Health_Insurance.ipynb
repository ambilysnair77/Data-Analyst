# %% [markdown]
# <h2><b>Python Programm For Medical Health Insurance</b></h2>

# %% [markdown]
#  <h3><b><li>Register in Health Insurance Plan for self and Family members</li>
#     <li>Calculating BMI</li>
#     <li>Viewing the Plan</li>
#                      <li>What is the Estimated insurance for one person each from the given details</li></b></h3>

# %%
import os#importing os module
import re # Importing re module 
import sys # importing system module

# %%
# declaring a class of HealthInsurance
class healthinsurance: 
    print("*"*40,"Welcome to Policy Bazar","*"*40)
    print("*"*30,"Top Family health Insurance Plan","*"*30)
    
    #enter the personal details.....
    gender=int(input("Please click on \n 1.Male \n 2.Female"))
    name=input("Enter your Name")
    age=int(input("Enter your age"))
    
    #to find out body mass index
    height = float(input("Enter the height in cm: "))  
    weight = float(input("Enter the weight in kg: "))
    bmi= weight / (height/100)**2  
    viewbmi=print("Your bmi is",bmi)
    smoker=int(input("Enter 1 if u are smoker and enter 0 if you are not"))
    num_of_children=int(input("Enter number of children"))
    mobileno=input("Enter your mobile number")
    phonevalid=re.fullmatch('[6-9][0-9]{9}',mobileno)
    if phonevalid!=None:
        print('Valid Number')
    else:
        #break
        #sys.exit()
        #raise Exception("The number is not valid...reenter the number")
        print("Invalid Number try again")
    print()
    # declaring the function for choosing for who,e we are taking insurance
    def insurancefor(self):
        print("*"*40,"Tell Us who would you like to Insure","*"*40)
        
        #from the Given Option Choose for whom you are taking Insurance
        choose=int(input("Please click on \n 1.Me \n 2.Me+My Wife \n 3.Me + My Wife and 1 child \n 4.Me + My Wife and 2 child \n 5.My parents \n 6.Other Members "))
        
        #Enter the age group for selected members
        if(choose==1):
            selectage=int(input("Select the age group  \n 1.1-10 \n 2.10-20 \n 3.20-30 \n 4.30-40 \n 5.40-50 \n 6.50-60 \n 7.60-70 \n 8.70-80 \n 9.80-90 \n 10.90-100"))
        elif(choose==2):
             selectage=int(input("Select age of the Eldest person \n  3.20-30 \n 4.30-40 \n 5.40-50 \n 6.50-60 \n 7.60-70 \n 8.70-80 \n 9.80-90 \n 10.90-100"))
        elif(choose==3):
            selectage=int(input("Select age of the Eldest person \n  3.20-30 \n 4.30-40 \n 5.40-50 \n 6.50-60 \n 7.60-70 \n 8.70-80 \n 9.80-90 \n 10.90-100"))
            selectage=int(input("Select age of the Child \n 1.1-10 \n2.10-20 \n"))
        elif(choose==4):
            selectage=int(input("Select age of the Eldest person \n  3.20-30 \n 4.30-40 \n 5.40-50 \n 6.50-60 \n 7.60-70 \n 8.70-80 \n 9.80-90 \n 10.90-100"))
            selectage=int(input("Select age of the Eldest Child \n 1.1-10 \n2.10-20 \n"))
        elif(choose==5):
             selectage=int(input("Select age of the Eldest person \n  3.20-30 \n 4.30-40 \n 5.40-50 \n 6.50-60 \n 7.60-70 \n 8.70-80 \n 9.80-90 \n 10.90-100"))
        elif(choose==6):
            
            #Selecting other family mebers for insurance.
            print("My Family","*"*40)
            choose1=int(input("Please click on \n 1.self \n 2.Spouse \n 3.Child \n 4.Father  \n 5.Mother \n 6.Father in law \n7.Mother in law "))
            
            #enetring the age group of selecter member.
            if(choose1==1):
                selectage=int(input("Select the age group  \n 1.1-10 \n2.10-20 \n 3.20-30 \n 4.30-40 \n 5.40-50 \n 6.50-60 \n 7.60-70 \n 8.70-80 \n 9.80-90 \n 10.90-100"))
            elif(choose1==2):
                selectage=int(input("Select age of the  person \n 1.20-30 \n 2.30-40 \n 3.40-50 \n 4.50-60 \n 5.60-70 \n 6.70-80 \n 9.80-90 \n 10.90-100"))
            elif(choose1==3):
                selectage=int(input("Select Child \n  1.Daughter \n 2.Son"))
                selectage=int(input("Select age of the Child \n 1.1-10 \n2.10-20 \n"))
            elif(choose1==4):
                selectage=int(input("Select age of the  person \n  1.20-30 \n 2.30-40 \n 3.40-50 \n 4.50-60 \n 5.60-70 \n 6.70-80 \n 7.80-90 \n 8.90-100"))
            elif(choose1==5):
                selectage=int(input("Select age of the  person \n  1.20-30 \n 2.30-40 \n 3.40-50 \n 4.50-60 \n 5.60-70 \n 6.70-80 \n 7.80-90 \n 8.90-100"))
            elif(choose1==6):
                selectage=int(input("Select age of the  person \n  1.20-30 \n 2.30-40 \n 3.40-50 \n 4.50-60 \n 5.60-70 \n 6.70-80 \n 7.80-90 \n 8.90-100"))
            elif(choose1==7):
                selectage=int(input("Select age of the  person \n  1.20-30 \n 2.30-40 \n 3.40-50 \n 4.50-60 \n 5.60-70 \n 6.70-80 \n 7.80-90 \n 8.90-100"))
            
            #After entering the details click on contiue for further procedure
            clicknext1=int(input("Please click on \n 1.Continue \n 2.TrynAgain"))
            if (clicknext1==1):
                health.entercity()
                #print("hi")
            else:
                print("Choose again")
                #break
            
        clicknext2=int(input("Please click on \n 1.Continue \n 2.TrynAgain"))
        if (clicknext2==1):
            print()
            health.entercity()
        #print("hi")
        else:
            print("Choose again")
            #break
    
    # defing the function for entering a city where you are living
    def entercity(self):
        #Given some popular cities
        print("Popular cities....\t Bengaluru. \t LuckNow. \t Kolkatha. \t Mumbai. \t Chennai. \t Delhi")
        print()
        city=input("Enter City or PinCode")
        clicknext3=int(input("Please click on \n 1.Continue \n 2.TryAgain"))
        if (clicknext3==1):
            #calling a function using class object
            health.healthplan()
            #print("hi")
        else:
            print("Choose again")
    
    #defining a function for choosing the plan
    def healthplan(self):
        print()
        print("*********Health Plan***********")
        print("Just few last details.......To help us find the right health plan for you")
        print("Does any member have an existing illness or medical history?\nThis helps us find plans that cover your condition and avoid claim rejection")
        print()
        choose=int(input("Please click on \n 1.Existing Illness \n BP,Diabetes, Heart Conditions,Asthama etc \n 2.Covid 19 \n 3.Surgical Procedure \n 4.None of these "))
        # calling a function to voew the plan
        print()
        health.viewplan()
     
    # defing function for viewing insurance plan   
    def viewplan(self):
        print("Choose your plan")
        print()
        print("Care Classic.....\n Coverup Amount:5lac \n Premium:1600/Month")
        print()
        print("1Crore Super Saver.....\n Coverup Amount:1cr \n Premium:1500/Month")
        print()
        print("Health Optima.....\n Coverup Amount:5lac \n Premium:1205/Month")
        
        clicknext=int(input("Please click on \n 1.Submit \n 2.Exit"))
        if (clicknext==1):
            #calling a function
            #find out what estimated cost for one person
            health.estimated_insurance_cost()
        else:
            print("****************Thank you visit Again.....****************")
            #break
       
    
        print("***************************************************************************")

    #define the function to calculate insurance   
    def calculate_insurance_cost(self,age, sex, bmi, num_of_children, smoker):
        print()
        estimated_cost = 250*age - 128*sex + 370*bmi + 425*num_of_children + 24000*smoker - 12500
        print("The estimated insurance cost for this person is " + str(estimated_cost) + "dollars.")
        return estimated_cost
    
    #define the function and passing values 
    def estimated_insurance_cost(self):
        insurance_cost = health.calculate_insurance_cost(self.age, self.gender, self.bmi,self.num_of_children,self.smoker) 
        
        
    
#created one object of class healthinsurance
health=healthinsurance()
#call the function using class object
health.insurancefor()
